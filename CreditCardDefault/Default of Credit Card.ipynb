# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns

# %%
df = pd.read_csv("./defaultcc.csv",  header=1)
col_names = ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT_1','BILL_AMT_2','BILL_AMT_3','BILL_AMT_4','BILL_AMT_5','BILL_AMT_6','PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'LABEL']
df.columns = col_names;

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...    BILL_AMT_4  BILL_AMT_5  BILL_AMT_6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...             0           0           0         0       689         0
# 1  ...          3272        3455        3261         0      1000      1000
# 2  ...         14331       14948       15549      1518      1500      1000
# 3  ...         28314       28959       29547      2000      2019      1200
# 4  ...         20940       19146       19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  LABEL
# ...

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df[['LIMIT_BAL', 'SEX', 'EDUCATION']])

# %%
df.query('EDUCATION == 0')
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 3769    3770     290000    2          0         2   38      1     -1     -1
# 5945    5946     270000    1          0         2   39      1     -1     -1
# 6876    6877     360000    1          0         2   30      0      0     -1
# 14631  14632     350000    2          0         2   53     -1     -1     -1
# 15107  15108     210000    1          0         2   45     -2     -2     -2
# 16881  16882     100000    1          0         2   37      0      0     -2
# 16896  16897     200000    1          0         2   40      1     -2     -1
# 17414  17415     230000    2          0         2   47     -1     -1     -1
# 19920  19921      50000    2          0         1   40      0      0      0
# 20030  20031     200000    2          0         2   30     -1     -1      2
# 23234  23235     220000    2          0         1   35     -2     -2     -2
# ...

# %%
corr = df.corr()
corr
# Out:
#                   ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID          1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL   0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX         0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION   0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE   -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE         0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_1      -0.030575  -0.271214 -0.057643   0.105364  0.019917 -0.039447
# PAY_2      -0.011215  -0.296382 -0.070771   0.121566  0.024199 -0.050148
# PAY_3      -0.018494  -0.286123 -0.066096   0.114025  0.032688 -0.053048
# PAY_4      -0.002735  -0.267460 -0.060173   0.108793  0.033122 -0.049722
# PAY_5      -0.022199  -0.249411 -0.055064   0.097520  0.035629 -0.053826
# PAY_6      -0.020270  -0.235195 -0.044008   0.082316  0.034345 -0.048773
# ...

# %%
plt.subplots(figsize=(12,10))  
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
abs(corr)
# Out:
#                   ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID          1.000000   0.026179  0.018497   0.039177  0.029079  0.018678
# LIMIT_BAL   0.026179   1.000000  0.024755   0.219161  0.108139  0.144713
# SEX         0.018497   0.024755  1.000000   0.014232  0.031389  0.090874
# EDUCATION   0.039177   0.219161  0.014232   1.000000  0.143464  0.175061
# MARRIAGE    0.029079   0.108139  0.031389   0.143464  1.000000  0.414170
# AGE         0.018678   0.144713  0.090874   0.175061  0.414170  1.000000
# PAY_1       0.030575   0.271214  0.057643   0.105364  0.019917  0.039447
# PAY_2       0.011215   0.296382  0.070771   0.121566  0.024199  0.050148
# PAY_3       0.018494   0.286123  0.066096   0.114025  0.032688  0.053048
# PAY_4       0.002735   0.267460  0.060173   0.108793  0.033122  0.049722
# PAY_5       0.022199   0.249411  0.055064   0.097520  0.035629  0.053826
# PAY_6       0.020270   0.235195  0.044008   0.082316  0.034345  0.048773
# ...

# %%
plt.subplots(figsize=(12,10))  
sns.heatmap(abs(corr), 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
plt.hist(df.query('LABEL == 0')[['LIMIT_BAL']].values, color='blue')
plt.hist(df.query('LABEL == 1')[['LIMIT_BAL']].values, color='red')
plt.show()

plt.hist(df.query('LABEL == 0')[['PAY_1']].values, color='blue')
plt.hist(df.query('LABEL == 1')[['PAY_1']].values, color='red')
plt.show()

# %%
df.query('LABEL == 0').mean()
# Out:
# ID             15064.893982
# LIMIT_BAL     178099.726074
# SEX                1.614150
# EDUCATION          1.841337
# MARRIAGE           1.558637
# AGE               35.417266
# PAY_1             -0.211222
# PAY_2             -0.301917
# PAY_3             -0.316256
# PAY_4             -0.355633
# PAY_5             -0.389488
# PAY_6             -0.405624
# BILL_AMT_1     51994.227273
# BILL_AMT_2     49717.435670
# BILL_AMT_3     47533.365605
# BILL_AMT_4     43611.165254
# BILL_AMT_5     40530.445343
# BILL_AMT_6     39042.268704
# PAY_AMT1        6307.337357
# PAY_AMT2        6640.465074
# PAY_AMT3        5753.496833
# PAY_AMT4        5300.529319
# PAY_AMT5        5248.220296
# PAY_AMT6        5719.371769
# LABEL              0.000000
# dtype: float64

# %%
df.query('LABEL == 1').mean()
# Out:
# ID             14773.781947
# LIMIT_BAL     130109.656420
# SEX                1.567058
# EDUCATION          1.894665
# MARRIAGE           1.528029
# AGE               35.725738
# PAY_1              0.668174
# PAY_2              0.458258
# PAY_3              0.362116
# PAY_4              0.254521
# PAY_5              0.167872
# PAY_6              0.112116
# BILL_AMT_1     48509.162297
# BILL_AMT_2     47283.617842
# BILL_AMT_3     45181.598855
# BILL_AMT_4     42036.950573
# BILL_AMT_5     39540.190476
# BILL_AMT_6     38271.435503
# PAY_AMT1        3397.044153
# PAY_AMT2        3388.649638
# PAY_AMT3        3367.351567
# PAY_AMT4        3155.626733
# PAY_AMT5        3219.139542
# PAY_AMT6        3441.482068
# LABEL              1.000000
# dtype: float64

# %% [markdown]
# # Histograms colored by class label

# %%
from matplotlib.colors import ListedColormap
cm3 = ListedColormap(['#0000aa', '#ff2020', '#50ff50'])
cm3(0)
# Out:
# (0.0, 0.0, 0.6666666666666666, 1.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f1fe0337db0f> in <module>()
# ----> 1 df.iloc[:, i]
#
# NameError: name 'i' is not defined

# %%
import math

fig, axes = plt.subplots(math.ceil(len(df.columns)/2), 2, figsize=(20,30))
defaulted = df[df.LABEL == 0]
notdefaulted = df[df.LABEL == 1]
ax = axes.ravel()

for i in range(len(df.columns)):
    _, bins = np.histogram(df.iloc[:, i],bins=50)
    ax[i].hist(defaulted.iloc[:,i], bins=bins,color=cm3(0), alpha= .5)
    ax[i].hist(notdefaulted.iloc[:,i], bins=bins, color=cm3(2), alpha=.5)
    ax[i].set_title(col_names[i])
    ax[i].set_yticks(())
ax[0].set_xlabel("Feature magnitude")
ax[0].set_ylabel("Frequency")
ax[0].legend(["Defaulted", "Not Defaulted"], loc="best")
fig.tight_layout()

# %% [markdown]
# # Pair plots colored by class label

# %%
y_train = df['LABEL']
y_train.values
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df, c=y_train.values, figsize=(15,15), marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FC1A3FDD68>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1']], c=y_train.values, figsize=(15,15), marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FC34BD5EF0>,
# ...
#       dtype=object)

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
df_scaled = scaler.transform(df)

# %%
df_scaled
# Out:
# array([[-1.73199307, -1.13672015,  0.81016074, ..., -0.31413612,
#         -0.29338206,  1.87637834],
#        [-1.7318776 , -0.3659805 ,  0.81016074, ..., -0.31413612,
#         -0.18087821,  1.87637834],
#        [-1.73176213, -0.59720239,  0.81016074, ..., -0.24868274,
#         -0.01212243, -0.53294156],
#        ...,
#        [ 1.73176213, -1.05964618, -1.23432296, ..., -0.18322937,
#         -0.11900109,  1.87637834],
#        [ 1.7318776 , -0.67427636, -1.23432296, ...,  3.15253642,
#         -0.19190359,  1.87637834],
#        [ 1.73199307, -0.90549825, -1.23432296, ..., -0.24868274,
#         -0.23713013,  1.87637834]])

# %%
pca = PCA()
pca.fit(df_scaled)
pca.components_
# Out:
# array([[ 6.13621364e-03,  6.56689948e-02, -2.20334094e-02,
#          1.98944035e-02, -5.59935127e-03,  1.40049976e-02,
#          1.64449908e-01,  1.97230169e-01,  2.03155267e-01,
#          2.09852302e-01,  2.13589329e-01,  2.08798460e-01,
#          3.32749483e-01,  3.44161974e-01,  3.48104850e-01,
#          3.52246464e-01,  3.50129080e-01,  3.42926979e-01,
#          9.27266193e-02,  7.73614328e-02,  8.50457032e-02,
#          7.64832568e-02,  7.40783012e-02,  6.87393456e-02,
#          3.97331219e-02],
#        [ 2.27945096e-02,  3.11519817e-01,  3.09597152e-02,
#         -8.81423727e-02, -3.98657250e-02,  6.28126443e-02,
#         -2.96687453e-01, -3.27905344e-01, -3.34981981e-01,
#         -3.34380659e-01, -3.21318037e-01, -2.95919600e-01,
#          1.43360240e-01,  1.43844935e-01,  1.49725998e-01,
#          1.49019421e-01,  1.47056869e-01,  1.44989442e-01,
#          1.48624258e-01,  1.38625266e-01,  1.50039892e-01,
# ...

# %%
pca = PCA(n_components=0.95)
X_reduced = pca.fit_transform(df_scaled)
X_reduced
# Out:
# array([[-1.81178577e+00, -1.30879539e+00, -4.81495994e-01, ...,
#         -9.13687302e-01, -3.71204515e-01, -8.40161769e-02],
#        [-6.82513487e-01, -2.44501667e+00,  1.14175108e+00, ...,
#         -1.30755024e-01, -3.40736320e-01,  6.96934575e-01],
#        [-8.69346490e-01, -1.00875097e+00,  5.76909908e-01, ...,
#          5.26953355e-01,  2.86470050e-01,  3.51900562e-03],
#        ...,
#        [ 4.75859356e-01, -3.56976557e+00,  3.84488816e-01, ...,
#          1.16306400e+00,  3.63736042e-02, -6.26234462e-01],
#        [ 7.29528737e-01,  4.22949400e-01,  1.67188999e-01, ...,
#         -9.53283305e-01,  1.30183005e-01, -9.24056402e-01],
#        [-5.21101585e-02, -1.09593737e+00, -1.56104557e+00, ...,
#         -6.34432483e-01,  7.30381491e-01,  1.83074780e-01]])

# %%
plt.figure(figsize=(8,8))

label_arr = df["LABEL"].values

label0_mask = label_arr == 0
label0_mask
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
X_reduced
# Out:
# array([[-1.81178577e+00, -1.30879539e+00, -4.81495994e-01, ...,
#         -9.13687302e-01, -3.71204515e-01, -8.40161769e-02],
#        [-6.82513487e-01, -2.44501667e+00,  1.14175108e+00, ...,
#         -1.30755024e-01, -3.40736320e-01,  6.96934575e-01],
#        [-8.69346490e-01, -1.00875097e+00,  5.76909908e-01, ...,
#          5.26953355e-01,  2.86470050e-01,  3.51900562e-03],
#        ...,
#        [ 4.75859356e-01, -3.56976557e+00,  3.84488816e-01, ...,
#          1.16306400e+00,  3.63736042e-02, -6.26234462e-01],
#        [ 7.29528737e-01,  4.22949400e-01,  1.67188999e-01, ...,
#         -9.53283305e-01,  1.30183005e-01, -9.24056402e-01],
#        [-5.21101585e-02, -1.09593737e+00, -1.56104557e+00, ...,
#         -6.34432483e-01,  7.30381491e-01,  1.83074780e-01]])

# %%
X_reduced[label0_mask]
# Out:
# array([[-0.86934649, -1.00875097,  0.57690991, ...,  0.52695335,
#          0.28647005,  0.00351901],
#        [-0.22069917, -0.74491802, -0.68601404, ..., -0.66089408,
#          0.44790002,  0.03696635],
#        [-0.87060386, -0.03558964, -0.9773451 , ...,  0.0692519 ,
#          1.27260623,  0.20235471],
#        ...,
#        [ 0.35800538,  0.89700933,  1.70534813, ...,  0.26834451,
#          1.05852455, -0.67732217],
#        [ 2.50451383,  0.85499677, -1.74228837, ..., -0.41918518,
#         -0.801709  ,  0.16551019],
#        [-1.78440164,  0.06123812, -0.50671286, ...,  0.68870831,
#         -0.05188176, -0.40353462]])

# %%
label1_mask = label_arr == 1
label1_mask
# Out:
# array([ True,  True, False, ...,  True,  True,  True])

# %%
X_reduced[label1_mask]
# Out:
# array([[-1.81178577, -1.30879539, -0.48149599, ..., -0.9136873 ,
#         -0.37120452, -0.08401618],
#        [-0.68251349, -2.44501667,  1.14175108, ..., -0.13075502,
#         -0.34073632,  0.69693457],
#        [ 1.65762198, -2.93267349,  0.61135583, ..., -0.01644311,
#         -0.20526227,  0.47332878],
#        ...,
#        [ 0.47585936, -3.56976557,  0.38448882, ...,  1.163064  ,
#          0.0363736 , -0.62623446],
#        [ 0.72952874,  0.4229494 ,  0.167189  , ..., -0.95328331,
#          0.13018301, -0.9240564 ],
#        [-0.05211016, -1.09593737, -1.56104557, ..., -0.63443248,
#          0.73038149,  0.18307478]])

# %%
plt.scatter(X_reduced[label0_mask][:,0], X_reduced[label0_mask][:,1], c='Red', alpha=0.1)
plt.scatter(X_reduced[label1_mask][:,0], X_reduced[label1_mask][:,1], c='Blue', alpha=0.1)
plt.show()

# %%
plt.scatter(X_reduced[label1_mask][:,0], X_reduced[label1_mask][:,1], c='Blue', alpha=0.1)
plt.scatter(X_reduced[label0_mask][:,0], X_reduced[label0_mask][:,1], c='Red', alpha=0.1)

plt.show()

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split

# %%
df = df.drop(['ID'], axis=1)
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
X = df.values
y = df['LABEL'].values
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape
# Out:
# (22500, 24)

# %%
X_test
# Out:
# array([[ 30000,      2,      3, ...,      0,   1100,      0],
#        [ 30000,      1,      2, ...,   2000,     24,      0],
#        [260000,      1,      1, ...,   3017,   2736,      0],
#        ...,
#        [330000,      2,      5, ...,  30032,   4005,      0],
#        [200000,      1,      1, ...,      0,      0,      0],
#        [150000,      1,      1, ...,   1700,      0,      0]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = model.predict(X_test)

# %%
len(y_pred[y_pred == 1])
# Out:
# 1597

# %%
len(y_test[y_test == 1])
# Out:
# 1597

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
precision_score(y_test, y_pred)
# Out:
# 1.0

# %%
recall_score(y_test, y_pred)
# Out:
# 1.0

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.tree import export_graphviz
